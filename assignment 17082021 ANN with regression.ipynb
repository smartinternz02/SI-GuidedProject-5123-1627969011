# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("50_Startups.csv")

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87              NaN  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08             NaN        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.isnull().any()
# Out:
# R&D Spend          False
# Administration      True
# Marketing Spend     True
# State              False
# Profit             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# R&D Spend          0
# Administration     1
# Marketing Spend    1
# State              0
# Profit             0
# dtype: int64

# %%
dataset.head(25)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87              NaN  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08             NaN        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9f2b259887ef> in <module>
# ----> 1 x.shape
#
# NameError: name 'x' is not defined

# %%
x = dataset.iloc[:, 0:4]
y = dataset.iloc[:, 2]

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 0   165349.20       136897.80        471784.10    New York
# 1   162597.70       151377.59        443898.53  California
# 2   153441.51       101145.55        407934.54     Florida
# 3   144372.41       118671.85        383199.62    New York
# 4   142107.34        91391.77        366168.42     Florida
# 5   131876.90        99814.71        362861.36    New York
# 6   134615.46       147198.87              NaN  California
# 7   130298.13       145530.06        323876.68     Florida
# 8   120542.52       148718.95        311613.29    New York
# 9   123334.88       108679.17        304981.62  California
# 10  101913.08             NaN        229160.95     Florida
# 11  100671.96        91790.61        249744.55  California
# 12   93863.75       127320.38        249839.44     Florida
# 13   91992.39       135495.07        252664.93  California
# 14  119943.24       156547.42        256512.92     Florida
# ...

# %%
type("Marketing Spend")
# Out:
# str

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       49.000000        49.000000      50.000000
# mean    73721.615600   121564.038163    212725.266735  112012.639200
# std     45902.256482    28264.721000    122959.103760   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103057.490000    134050.070000   90138.902500
# 50%     73051.080000   122782.750000    214634.810000  107978.190000
# 75%    101602.800000   145077.580000    299737.290000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
dataset["Marketing Spend"].fillna(dataset["Marketing Spend"].mode()[0],inplace = True)

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87             0.00  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08             NaN        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.isnull().sum()
# Out:
# R&D Spend          0
# Administration     1
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
type("Administration")
# Out:
# str

# %%
dataset["Administration"].fillna(dataset["Administration"].mode()[0],inplace = True)

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87             0.00  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08        51283.14        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-38484dfea833> in <module>
# ----> 1 sc = StandardScaler()
#       2 x_train = sc.fit_transform(x_train)
#       3 x_test = sc.fit_transform(x_test)
#       4
#
# NameError: name 'StandardScaler' is not defined

# %%
from sklearn.preprocessing import StandardScaler
d = StandardScaler()
p = d.fit_transform(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b7a4e8e57d08> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 d = StandardScaler()
# ----> 3 p = d.fit_transform(p)
#
# NameError: name 'p' is not defined

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6c10289a8da7> in <module>
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
p = np.array([[1,2,3],[-52,8,10000],[4,5,6]])

# %%
p
# Out:
# array([[    1,     2,     3],
#        [  -52,     8, 10000],
#        [    4,     5,     6]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
regression=Sequential()

# %%
regression

# %%
x_train.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d85548492a24> in <module>
# ----> 1 x_train.shape()
#
# NameError: name 'x_train' is not defined

# %%
x.train[0:5,:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-3efb85d00a58> in <module>
# ----> 1 x.train[0:5,:]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'train'

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-2132a220a582> in <module>
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b1d7152231c3> in <module>
#       1 sc = StandardScaler()
# ----> 2 x_train = sc.fit_transform(x_train)
#       3 x_test = sc.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %%
regression.add(Dense( units = 20 , kernel_initializer="random_uniform" , activation = "relu"))
# Out:
# WARNING:tensorflow:From C:\Users\utkar\Anaconda3\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
regression

# %%
x.shape
# Out:
# (50, 4)

# %%
regression.add(Dense( units = 40
                     , kernel_initializer="random_uniform" , activation = "relu"))

# %%
regression.add(Dense( units = 40
                     , kernel_initializer="random_uniform" , activation = "relu"))

# %%
x = dataset.iloc[:,1:].values
y = dataset.iloc[:,0:1].values

# %%
x
# Out:
# array([[136897.8, 471784.1, 'New York', 192261.83],
#        [151377.59, 443898.53, 'California', 191792.06],
#        [101145.55, 407934.54, 'Florida', 191050.39],
#        [118671.85, 383199.62, 'New York', 182901.99],
#        [91391.77, 366168.42, 'Florida', 166187.94],
#        [99814.71, 362861.36, 'New York', 156991.12],
#        [147198.87, 0.0, 'California', 156122.51],
#        [145530.06, 323876.68, 'Florida', 155752.6],
#        [148718.95, 311613.29, 'New York', 152211.77],
#        [108679.17, 304981.62, 'California', 149759.96],
#        [51283.14, 229160.95, 'Florida', 146121.95],
#        [91790.61, 249744.55, 'California', 144259.4],
#        [127320.38, 249839.44, 'Florida', 141585.52],
#        [135495.07, 252664.93, 'California', 134307.35],
#        [156547.42, 256512.92, 'Florida', 132602.65],
#        [122616.84, 261776.23, 'New York', 129917.04],
#        [121597.55, 264346.06, 'California', 126992.93],
#        [145077.58, 282574.31, 'New York', 125370.37],
# ...

# %%
y
# Out:
# array([[165349.2 ],
#        [162597.7 ],
#        [153441.51],
#        [144372.41],
#        [142107.34],
#        [131876.9 ],
#        [134615.46],
#        [130298.13],
#        [120542.52],
#        [123334.88],
#        [101913.08],
#        [100671.96],
#        [ 93863.75],
#        [ 91992.39],
#        [119943.24],
#        [114523.61],
#        [ 78013.11],
#        [ 94657.16],
#        [ 91749.16],
#        [ 86419.7 ],
#        [ 76253.86],
#        [ 78389.47],
#        [ 73994.56],
#        [ 67532.53],
#        [ 77044.01],
#        [ 64664.71],
#        [ 75328.87],
#        [ 72107.6 ],
#        [ 66051.52],
#        [ 65605.48],
#        [ 61994.48],
#        [ 61136.38],
#        [ 63408.86],
#        [ 55493.95],
#        [ 46426.07],
#        [ 46014.02],
#        [ 28663.76],
#        [ 44069.95],
#        [ 20229.59],
#        [ 38558.51],
#        [ 28754.33],
#        [ 27892.92],
#        [ 23640.93],
#        [ 15505.73],
#        [ 22177.74],
# ...

# %%
regression.compile(optimizer = "adam",loss = "binary_crosentropy",metrics = ["accuracy"])

# %%
regression.fit(x_train,y_train , epochs = 25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-9ff71ff8284f> in <module>
# ----> 1 regression.fit(x_train,y_train , epochs = 25)
#       2
#       3
#
# NameError: name 'x_train' is not defined

# %%
regression.add(Dense( units = 1 , kernel_initializer="random_uniform" , activation = "sigmoid"))

# %%
regression.fit(x_train,y_train , epochs = 25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c90da8b0b1de> in <module>
# ----> 1 regression.fit(x_train,y_train , epochs = 25)
#
# NameError: name 'x_train' is not defined

# %%
regression.fit(x_train,y_train , epochs = 25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-c90da8b0b1de> in <module>
# ----> 1 regression.fit(x_train,y_train , epochs = 25)
#
# NameError: name 'x_train' is not defined

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
regression.fit(x ,y , epochs = 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-b27f8d7073b6> in <module>
# ----> 1 regression.fit(x ,y , epochs = 30)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     707         steps=steps_per_epoch,
#     708         validation_split=validation_split,
# --> 709         shuffle=shuffle)
#     710
#     711     # Prepare validation data.
#
# ...

# %%
regression.fit(x_train, y_train,epochs = 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-12c05d71aff8> in <module>
# ----> 1 regression.fit(x_train, y_train,epochs = 30)
#
# NameError: name 'x_train' is not defined

# %%
ypred =regression.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-d4a1acfcc500> in <module>
# ----> 1 ypred =regression.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
X_test=sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b6a4335b0bf6> in <module>
#       1 sc=StandardScaler()
# ----> 2 x_train=sc.fit_transform(x_train)
#       3 X_test=sc.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.preprocessing import StandardScaler
d = StandardScaler()
p = d.fit_transform(p)

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-9094ab4ad7bf> in <module>
#       1 sc=StandardScaler()
# ----> 2 x_train=sc.fit_transform(x_train)
#       3 x_test=sc.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-9094ab4ad7bf> in <module>
#       1 sc=StandardScaler()
# ----> 2 x_train=sc.fit_transform(x_train)
#       3 x_test=sc.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
X_test=sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-b6a4335b0bf6> in <module>
#       1 sc=StandardScaler()
# ----> 2 x_train=sc.fit_transform(x_train)
#       3 X_test=sc.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
X_test=sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b6a4335b0bf6> in <module>
#       1 sc=StandardScaler()
# ----> 2 x_train=sc.fit_transform(x_train)
#       3 X_test=sc.fit_transform(x_test)
#
# NameError: name 'x_train' is not defined

# %%
regression.compile(optimizer = "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
regression.fit(x_train ,y_test , epochs = 50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-d71e268dc769> in <module>
# ----> 1 regression.fit(x_train ,y_test , epochs = 50)
#       2
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     707         steps=steps_per_epoch,
#     708         validation_split=validation_split,
# --> 709         shuffle=shuffle)
#     710
#     711     # Prepare validation data.
#
# ...

# %%
ypred = regression.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-e3d2c1f071d0> in <module>
# ----> 1 ypred = regression.predict(x_test)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1076           verbose=verbose,
#    1077           steps=steps,
# -> 1078           callbacks=callbacks)
#    1079
#    1080   def reset_metrics(self):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     155
# ...

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-9094ab4ad7bf> in <module>
#       1 sc=StandardScaler()
# ----> 2 x_train=sc.fit_transform(x_train)
#       3 x_test=sc.fit_transform(x_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
#     641     def partial_fit(self, X, y=None):
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [raw]
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
regression.compile(optimizer = "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
regression.fit(x_train, y_train,epochs = 350)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-477311c72818> in <module>
# ----> 1 regression.fit(x_train, y_train,epochs = 350)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     707         steps=steps_per_epoch,
#     708         validation_split=validation_split,
# --> 709         shuffle=shuffle)
#     710
#     711     # Prepare validation data.
#
# ...

# %%
ypred = regression.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-e3d2c1f071d0> in <module>
# ----> 1 ypred = regression.predict(x_test)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1076           verbose=verbose,
#    1077           steps=steps,
# -> 1078           callbacks=callbacks)
#    1079
#    1080   def reset_metrics(self):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     155
# ...

# %%
ypred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-aecbb823180e> in <module>
# ----> 1 ypred
#
# NameError: name 'ypred' is not defined
